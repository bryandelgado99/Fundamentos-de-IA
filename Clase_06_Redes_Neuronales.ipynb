# %% [markdown]
# <a href="https://colab.research.google.com/github/bryandelgado99/Fundamentos-de-IA/blob/main/Clase_06_Redes_Neuronales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio 1 - Transformación de temperatura

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
import pandas as pd

# Leemos el archivo
datos = pd.read_excel("/content/temperatura.xlsx")
print(datos.head())

# Separamos los datos de entrada y salida
X=datos["celsius"]
Y=datos["fahrenheit"]

# Dividimos datos en aprendizaje y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=25)

#Creamos la red neuronal de tipo percetrón
capa_entrada = tf.keras.layers.Dense(units=1, input_shape=[1])
modelo = tf.keras.Sequential([capa_entrada])

#Compilar el modelo
modelo.compile(optimizer='adam', loss='mean_squared_error')

#Entrenamiento del modelo
historial = modelo.fit(X_train, Y_train, epochs=100, batch_size=1)
print(historial)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       2 import tensorflow as tf
#       3 from tensorflow import keras
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\__init__.py:83
#      69     # We are not importing the rest of scikit-learn during the build
#      70     # process, as it may not be compiled yet
#      71 else:
#    (...)
#      77     # later is linked to the OpenMP runtime to make it possible to introspect
#      78     # it and importing it first would fail if the OpenMP dll cannot be found.
#      79     from . import (
#      80         __check_build,  # noqa: F401
#      81         _distributor_init,  # noqa: F401
#      82     )
# ---> 83     from .base import clone
# ...

# %%
#Impresión de historial
import matplotlib.pyplot as plt
plt.plot(historial.history["loss"])

#Función de pérdida
perdida = modelo.evaluate(X_test, Y_test)
print(perdida)

print(modelo.predict([25]))
# Out:
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_test_function.<locals>.test_function at 0x7a9e540f3760> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 384ms/step - loss: 655.2001
# 655.2001342773438
# 1/1 [==============================] - 0s 184ms/step
# [[36.398796]]
