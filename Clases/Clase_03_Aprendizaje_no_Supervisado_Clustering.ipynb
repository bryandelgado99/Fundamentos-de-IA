# %% [markdown]
# <a href="https://colab.research.google.com/github/bryandelgado99/Fundamentos-de-IA/blob/main/Clase_03_Aprendizaje_no_Supervisado_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Clase 03 - Aprendizaje No Supervisado**
# Tema: Clustering
#
# Fecha: 27/11/2023

# %% [markdown]
# ## Árbol de Decisión

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

#Leer archivo
datos=pd.read_csv("/content/diabetes_prediction_dataset.csv")
#Muestra los datos
datos.head()
#Describe las características del datasheet
datos.describe()

#Separar datos de entrada X con características y Y con etiquetas
x = datos.iloc[:,:-1] #Selecciona todas las columnas menos la última
y = datos.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state= 25)

#Creamos el modelo
modelo = DecisionTreeClassifier()

#Entrenamiento del modelo
modelo.fit(x_train,y_train)

#Probar el modelo y obtener datos
y_obtenido = modelo.predict(x_test)

#Métricas de evaluación
exactitud = accuracy_score(y_test, y_obtenido)
print(f"La excatitud obtenida es de: {exactitud}")

#Matriz de confusión
matriz = confusion_matrix(y_test, y_obtenido)

#Dibujamos la matriz de confusión por medio de mapa de calor
import seaborn as sns

sns.heatmap(matriz, annot=True, fmt='d', cmap="viridis")
plt.show()

print(f"La matriz de confusión obtenida equivale a: {matriz}")

#Nueva predicción
diabetes = modelo.predict([[15, 0, 5, 5, 10, 15.6, 0.01, 9]])
print(f"\nLa diabetes predecida es: {diabetes}")

##Caracteristicas e importancias - estas metricas solo para árbol de decisión
importancia = modelo.feature_importances_

#Obtener los nombres de las características
nombres = datos.columns.tolist()

for nombre_carc, impt in zip(importancia, nombres):
  print(f'{nombre_carc}, {impt}')
# Out:
# La excatitud obtenida es de: 0.95115
# La matriz de confusión obtenida equivale a: [[17808   526]
#  [  451  1215]]
#
# La diabetes predecida es: [0]
# 0.012750288096372813, gender
# 0.07201339289039468, age
# 0.005200441234742543, hypertension
# 0.00427544929517392, heart_disease
# 0.027927943139084997, smoking_history
# 0.12022987594286645, bmi
# 0.4896964865124983, HbA1c_level
# 0.2679061228888663, blood_glucose_level
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Vecino Cercano

# %%
#Leer archivo
datos=pd.read_csv("/content/diabetes_prediction_dataset.csv")
#Muestra los datos
datos.head()
#Describe las características del datasheet
datos.describe()

#Separar datos de entrada X con características y Y con etiquetas
x = datos.iloc[:,:-1] #Selecciona todas las columnas menos la última
y = datos.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state= 25)

#Algoritmo con vecino cercano y su número
vecino_cercano = KNeighborsClassifier(9)

#Entrenamiento del modelo
modelo.fit(x_train,y_train)

#Probar el modelo y obtener datos
y_obtenido = modelo.predict(x_test)

#Métricas de evaluación
exactitud = accuracy_score(y_test, y_obtenido)
print(f"La excatitud obtenida es de: {exactitud}")

#Matriz de confusión
matriz = confusion_matrix(y_test, y_obtenido)

#Dibujamos la matriz de confusión por medio de mapa de calor
import seaborn as sns

sns.heatmap(matriz, annot=True, fmt='d', cmap="viridis")
plt.show()

print(f"La matriz de confusión obtenida equivale a: {matriz}")

#Nueva predicción
diabetes = modelo.predict([[15, 0, 5, 5, 10, 15.6, 0.01, 9]])
print(f"\nLa diabetes predecida es: {diabetes}")
# Out:
# La excatitud obtenida es de: 0.9508
# La matriz de confusión obtenida equivale a: [[17802   532]
#  [  452  1214]]
#
# La diabetes predecida es: [0]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Ejercicio 2 - Árbol de decisión (Iris)

# %%
#Leer archivo
datos=pd.read_csv("/content/Iris.csv")
#Muestra los datos
datos.head()
#Describe las características del datasheet
datos.describe()
#Borra columna
datos = datos.drop('Id', axis=1)
print(datos)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Separar datos de entrada X con características y Y con etiquetas
x = datos.iloc[:,:-1] #Selecciona todas las columnas menos la última
y = datos.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state= 25)

#Creamos el modelo
modelo = DecisionTreeClassifier()

#Entrenamiento del modelo
modelo.fit(x_train,y_train)

#Probar el modelo y obtener datos
y_obtenido = modelo.predict(x_test)

#Métricas de evaluación
exactitud = accuracy_score(y_test, y_obtenido)
print(f"La excatitud obtenida es de: {exactitud}")

#Matriz de confusión
matriz = confusion_matrix(y_test, y_obtenido)
print(f"La matriz de confusión obtenida equivale a: {matriz}")

#Dibujamos la matriz de confusión por medio de mapa de calor
import seaborn as sns

sns.heatmap(matriz, annot=True, fmt='d', cmap="viridis")
plt.show()

sns.scatterplot(data=datos, x="SepalLengthCm", y="SepalWidthCm", hue="Species")

##Caracteristicas e importancias - estas metricas solo para árbol de decisión
importancia = modelo.feature_importances_

#Obtener los nombres de las características
nombres = datos.columns.tolist()

for nombre_carc, impt in zip(importancia, nombres):
  print(f'{nombre_carc}, {impt}')
# Out:
# La excatitud obtenida es de: 0.9666666666666667
# La matriz de confusión obtenida equivale a: [[ 9  0  0]
#  [ 0 12  1]
#  [ 0  0  8]]
# 0.0, SepalLengthCm
# 0.0, SepalWidthCm
# 0.06723037362231718, PetalLengthCm
# 0.9327696263776829, PetalWidthCm

# %%
''' Ejercicio 1
o	Longitud del sépalo 4.5 ancho del sépalo 3.2, longitud del pétalo 1.6 y ancho del pétalo 0.3
'''
ejercicio_1 = modelo.predict([[4.5, 3.2, 1.6, 0.3]])
print(f"\nLa flor predecida es: {ejercicio_1}")
# Out:
# La flor predecida es: ['Iris-setosa']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
''' Ejercicio 2
o	Longitud del sépalo 3 ancho del sépalo 2.2, longitud del pétalo 2.5 y ancho del pétalo 0.5
'''
ejercicio_2 = modelo.predict([[3, 2.2, 2.5, 0.5]])
print(f"\nLa flor predecida es: {ejercicio_2}")
# Out:
# La flor predecida es: ['Iris-setosa']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
